# %% [markdown]
# # Create html files for each restaruant

# %%
import csv
import pandas as pd

#CSV con los posteos y placeID (tab marto)
#df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQZKV6cTylp1mQnJXL8V7pQzDa2t9rvyrGv4rlse02Wkz_hyqchazE8CLZiUwLeYjCOGV0lM_PZ1bT2/pub?gid=1918594157&single=true&output=csv')

df = pd.read_csv('df_place_id.csv')

#Nombre restaurante
#Influencer list
#IG/WEB
#Telefono
#Servicios
#Dirección
#Map embed
#Horario
#Posteos IG

# %%
df['gmaps_url']
# Out:
# 0        https://maps.google.com/?cid=490313939449740110
# 1       https://maps.google.com/?cid=5964618193705152423
# 2       https://maps.google.com/?cid=4339105063233013450
# 3       https://maps.google.com/?cid=9425496120233880258
# 4       https://maps.google.com/?cid=2790271422869745219
#                              ...
# 890      https://maps.google.com/?cid=355777744971801154
# 891     https://maps.google.com/?cid=2219112532116629253
# 892      https://maps.google.com/?cid=735115375342848321
# 893    https://maps.google.com/?cid=12842313787906558312
# 894    https://maps.google.com/?cid=15564062661975943041
# Name: gmaps_url, Length: 895, dtype: object

# %%
df_place_id_filtered_bsas[df_place_id_filtered_bsas]

# %%
df_place_id_filtered = df[['place_id','nombre','sublocality_level_1','administrative_area_level_1','Influencer','telefono','opening_hours','instagram_embed_code','formatted_address','website','gmaps_url']]
df_place_id_filtered_bsas = df_place_id_filtered[df_place_id_filtered['administrative_area_level_1']=='Buenos Aires']


df_place_id_filtered_bsas
# Out:
#                         place_id                    nombre  \
# 0    ChIJyXG2WnzLvJURTvtSHe7xzQY                Neko Sushi
# 1    ChIJh3JJKim1vJURp6-gMKWUxlI                 Georgie's
# 2    ChIJ3ZK5jSy1vJURykYawRCZNzw               Cuervo Café
# 3    ChIJk8hwB5-1vJURwupcbsgWzoI                Sho Ku Pan
# 4    ChIJRz6gfke1vJURQy4TWxMJuSY             Corte Comedor
# ..                           ...                       ...
# 870  ChIJGYrhOcm1vJURoi-Baj3ugs0      La Fina Pizza & Love
# 871  ChIJ3_YRvdc0o5URF426622Yfts               Hotel Faena
# 876  ChIJjSIcnS20vJURTTlKe4xJk08    Parrilla El Pobre Luis
# 879  ChIJNUkrkZC1vJURuNJMCvjhlJ4             Guey Taqueria
# 883  ChIJ9T9sLWPLvJURps-VcfsPzqU  Cucina Paradiso Recoleta
#
#     sublocality_level_1 administrative_area_level_1  \
# 0          Villa Crespo                Buenos Aires
# 1             Chacarita                Buenos Aires
# 2               Palermo                Buenos Aires
# ...

# %%
print(str(df_place_id_filtered_bsas['instagram_embed_code'][0]).replace("['",'').replace("']","").replace("', '",""))
# Out:
# <blockquote class="instagram-media" data-instgrm-captioned data-instgrm-permalink="https://www.instagram.com/p/CtRnJlTutur/?utm_source=ig_embed&amp;utm_campaign=loading" data-instgrm-version="14" style=" background:#FFF; border:0; border-radius:3px; box-shadow:0 0 1px 0 rgba(0,0,0,0.5),0 1px 10px 0 rgba(0,0,0,0.15); margin: 1px; max-width:540px; min-width:326px; padding:0; width:99.375%; width:-webkit-calc(100% - 2px); width:calc(100% - 2px);"><div style="padding:16px;"> <a href="https://www.instagram.com/p/CtRnJlTutur/?utm_source=ig_embed&amp;utm_campaign=loading" style=" background:#FFFFFF; line-height:0; padding:0 0; text-align:center; text-decoration:none; width:100%;" target="_blank"> <div style=" display: flex; flex-direction: row; align-items: center;"> <div style="background-color: #F4F4F4; border-radius: 50%; flex-grow: 0; height: 40px; margin-right: 14px; width: 40px;"></div> <div style="display: flex; flex-direction: column; flex-grow: 1; justify-content: center;"> <div st
# ...

# %%
#import numpy as np
#df_place_id_filtered_bsas['Influencer'][0].split()[0]
print(set(str(df_place_id_filtered_bsas['Influencer'][0]).replace("['",'').replace("']","").replace(",","").replace("'"," ").split()))
# Out:
# {'bairesforkclub'}

# %%
df_place_id_filtered_bsas.columns
# Out:
# Index(['place_id', 'nombre', 'sublocality_level_1',
#        'administrative_area_level_1', 'Influencer', 'telefono',
#        'opening_hours', 'instagram_embed_code', 'formatted_address',
#        'website'],
#       dtype='object')

# %%
#Itero por cada place_id para traer la URL de la photo
for index, row in df_place_id_filtered_bsas.iterrows():
    resto_name = row['nombre']
    #address_link = row['address-link']
    telefono = row['telefono']
    address = row['formatted_address']
    opening_hours = row['opening_hours']
    influencers = row['Influencer']
    website = row['website']
    gmaps_url = row['gmaps_url']
    place_id = row['place_id']
    key_string = "https://www.google.com/maps/embed/v1/place?key=AIzaSyAN0om9mFmy1QN6Wf54tXAowK4eT0ZUPrU&q=place_id:"
    gmaps_embed_url = key_string+str(place_id)
    posts = str(row['instagram_embed_code']).replace("['",'').replace("']","").replace("', '","")

    # Generate the HTML content for the restaurant page
    html_content = f"""
<!-- /*
        * Template Name: Minimal
        * Template Author: Untree.co
        * Author URI: https://untree.co/
        * License: https://creativecommons.org/licenses/by/3.0/
        */ -->
<!doctype html>
<html lang="en">

<head>
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
    <meta name="author" content="Untree.co">
    <link rel="shortcut icon" href="favicon.png">
    <meta name="description" content="" />
    <meta name="keywords" content="" />
    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
    <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@400;700&family=PT+Mono&display=swap" rel="stylesheet">
    <link rel="stylesheet" href="../css/bootstrap.min.css">
    <link rel="stylesheet" href="../css/owl.carousel.min.css">
    <link rel="stylesheet" href="../css/owl.theme.default.min.css">
    <link rel="stylesheet" href="../css/jquery.fancybox.min.css">
    <link rel="stylesheet" href="../fonts/icomoon/style.css">
    <link rel="stylesheet" href="../fonts/flaticon/font/flaticon.css">
    <link rel="stylesheet" href="../css/aos.css">
    <link rel="stylesheet" href="../css/style.css">
    <title>Recomiendo. {resto_name}</title>
    <!-- Google AdSense Tags -->
    <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9164898974146308" crossorigin="anonymous"></script>
</head>

<body data-spy="scroll" data-target=".site-navbar-target" data-offset="100">
    <div class="site-mobile-menu site-navbar-target">
        <div class="site-mobile-menu-header">
            <div class="site-mobile-menu-close">
                <span class="icofont-close js-menu-toggle"></span>
            </div>
        </div>
        <div class="site-mobile-menu-body"></div>
    </div>
    <nav class="site-nav dark mb-5 site-navbar-target">
        <div class="container">
            <div class="site-navigation">
                <a href="../index.html" class="logo m-0">Recomiendo<span class="text-primary">.</span></a>
                <a href="../index.html" class="ml-auto float-right">
                    <span class="icon-arrow-left"></span>
                </a>
            </div>
        </div>
    </nav>
    <div class="untree_co-section untree_co-section-4 pb-0" id="portfolio-section">
        <div class="container">
            <div class="portfolio-single-wrap unslate_co--section" id="portfolio-single-section">
                <div class="portfolio-single-inner">
                    <h2 class="heading-portfolio-single-h2 text-black">{resto_name}</h2>
                    <div class="row mb-5 align-items-stretch">
                        <div class="col-lg-6 pl-lg-5">
                            <div class="row mb-3">
                                <div class="col-sm-6 col-md-6 col-lg-6 mb-4">
                                    <div class="detail-v1">
                                        <span class="detail-label">Recomendado por:</span>
                                        <span class="detail-val"><a href="https://www.instagram.com/bairesforkclub/">{influencers}</a></span>
                                    </div>
                                </div>
                                <div class="col-sm-6 col-md-6 col-lg-6 mb-4">
                                    <div class="detail-v1">
                                        <span class="detail-label">Instagram/Web</span>
                                        <span class="detail-val"><a href="{website}">{website}</a></span>
                                    </div>
                                </div>
                                <div class="col-sm-6 col-md-6 col-lg-6 mb-4">
                                    <div class="detail-v1" style="margin-bottom: 24px;">
                                        <span class="detail-label">Teléfono</span>
                                        <span class="detail-val">{telefono}</span><br>
                                    </div>
                                    <div class="detail-v1">
                                        <span class="detail-label">Servicios</span>
                                        <span class="detail-val">
                                            <ul>
                                                <li>Almuerzo ☀️</li>
                                                <li>Cena 🌑</li>
                                                <li>Retiro en el lugar 📦 </li>
                                                <li>Delivery 🛵</li>
                                                <li>Birra 🍺</li>
                                                <li>Vino 🍷</li>
                                            </ul>
                                        </span>
                                    </div>
                                </div>
                                <div class="col-sm-6 col-md-6 col-lg-6 mb-4">
                                    <div class="detail-v1">
                                        <span class="detail-label">Horario</span>
                                        <span class="detail-val">
                                            <ul>
                                                {opening_hours}
                                            </ul>
                                        </span>
                                    </div>
                                </div>
                                <div class="col">
                                    <div class="detail-v1">
                                        <span class="detail-label">Dirección</span>
                                        <span class="detail-val" style="margin-bottom: 24px;"><a href="{gmaps_url}">{address}</a></span>
                                        <span><iframe src="{gmaps_embed_url}" width="100%" height="200" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe></span>
                                    </div>
                                </div>
                            </div>
                        </div>
                        <div class="col-lg-6 mb-5 mb-lg-0">
                           {posts}
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </div>
    <div class="site-footer">
        <div class="container">
            <div class="row">
                <div class="col-12 text-center">
                    <p class=" mb-0">&copy; 2020. All Rights Reserved. Design by <a href="https://untree.co/" target="_blank" class=""><strong>Untree.co</strong></a></p>
                    <p class="">
                        <span class="mx-2">Twitter <a href="https://twitter.com/untree_co">@Untree_co</a></span>
                        <span>&bullet;</span>
                        <span class="mx-2">Facebook <a href="https://web.facebook.com/Untree.co">@Untree.co</a></span>
                    </p>
                </div>
            </div>
        </div> <!-- /.container -->
    </div> <!-- /.site-footer -->
    <script src="../js/jquery-3.4.1.min.js"></script>
    <script src="../js/popper.min.js"></script>
    <script src="../js/bootstrap.min.js"></script>
    <script src="../js/owl.carousel.min.js"></script>
    <script src="../js/jquery.animateNumber.min.js"></script>
    <script src="../js/jquery.waypoints.min.js"></script>
    <script src="../js/jquery.fancybox.min.js"></script>
    <script src="../js/aos.js"></script>
    <script src="../js/wave-animate.js"></script>
    <script src="../js/circle-progress.js"></script>
    <script src="../js/imagesloaded.pkgd.js"></script>
    <script src="../js/isotope.pkgd.min.js"></script>
    <script src="../js/jquery.easing.1.3.js"></script>
    <script src="../js/TweenMax.min.js"></script>
    <script src="../js/ScrollMagic.min.js"></script>
    <script src="../js/scrollmagic.animation.gsap.min.js"></script>
    <script src="../js/custom.js"></script>
</body>

</html>
        """

    # Save the HTML content to a file
    filename = f"{resto_name.replace(' ', '_').replace('/','_').lower()}.html"
    with open(filename, 'w') as htmlfile:
        htmlfile.write(html_content)

    print(f"Created {filename} for {resto_name}")
# Out:
# Created neko_sushi.html for Neko Sushi
# Created georgie's.html for Georgie's
# Created cuervo_café.html for Cuervo Café
# Created sho_ku_pan.html for Sho Ku Pan
# Created corte_comedor.html for Corte Comedor
# Created gordo_chanta_pizza.html for Gordo Chanta Pizza
# Created picaron.html for Picaron
# Created punto._café.html for punto. café
# Created cuadra.html for CUADRA
# Created obrador_restaurante.html for Obrador Restaurante
# Created ya_cabron.html for Ya cabron
# Created franca.html for FRANCA
# Created malcriada_cafe.html for Malcriada Cafe
# Created darien_café.html for Darien Café
# Created canti_bar.html for CANTI BAR
# Created argot.html for Argot
# Created la_sorellina_pizza_bar.html for La Sorellina Pizza Bar
# Created piedra_pasillo_al_fondo.html for Piedra Pasillo Al Fondo
# Created bocabajo_-_restoran_de_experiencias.html for BOCABAJO - Restoran de experiencias
# Created estudio.te.html for estudio.te
# Created verdín,_bar_de_café.html for Verdín, Bar de Café
# ...
